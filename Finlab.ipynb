# %% [markdown]
# <a href="https://colab.research.google.com/github/tingi0514/moneysearch/blob/Finlab/Finlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
print(datetime.datetime.now())
a=datetime.datetime.now().date
print()
print(type(a))
# Out:
# 2022-08-13 10:05:39.932730
# <built-in method date of datetime.datetime object at 0x7f8554e6ba80>
# <class 'builtin_function_or_method'>

# %%
! pip install finlab >log.txt

# %%
import finlab
dir(finlab)
# Out:
# ['LoginPanel',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'data',
#  'dataframe',
#  'get_token',
#  'logger',
#  'logging',
#  'login',
#  'os',
#  'threading',
#  'time',
#  'utils',
#  'utils_core']

# %%
from finlab import data
data.get('price:收盤價')
# Out:
# 輸入成功!
#             0015    0050   0051   0052   0053  0054   0055   0056   0057  \
# date
# 2007-04-23  9.54   57.85  32.83  38.40    NaN   NaN    NaN    NaN    NaN
# 2007-04-24  9.54   58.10  32.99  38.65    NaN   NaN    NaN    NaN    NaN
# 2007-04-25  9.52   57.60  32.80  38.59    NaN   NaN    NaN    NaN    NaN
# 2007-04-26  9.59   57.70  32.80  38.60    NaN   NaN    NaN    NaN    NaN
# 2007-04-27  9.55   57.50  32.72  38.40    NaN   NaN    NaN    NaN    NaN
# ...          ...     ...    ...    ...    ...   ...    ...    ...    ...
# 2022-09-12   NaN  115.40  55.15  97.25  56.35   NaN  23.26  28.56  82.60
# 2022-09-13   NaN  116.00  55.45  98.05  56.90   NaN  23.31  28.71  83.05
# 2022-09-14   NaN  113.65  54.95  95.95  55.85   NaN  23.03  28.35    NaN
# 2022-09-15   NaN  113.85  55.25  96.15  56.00   NaN  23.03  28.59  81.60
# 2022-09-16   NaN  112.55  54.80  95.10  55.30   NaN  23.06  28.28  80.85
#
# ...

# %%
import finlab
finlab.login('cGh0Tr7orzPWEI5AuemnvaJwUNWr2v1BbI0U2V6YnODsND6MavzW/L45qp/NBG6r#free')

from finlab import data
data.get('price:收盤價')
# Out:
# 輸入成功!
#             0015    0050   0051   0052   0053  0054   0055   0056   0057  \
# date
# 2007-04-23  9.54   57.85  32.83  38.40    NaN   NaN    NaN    NaN    NaN
# 2007-04-24  9.54   58.10  32.99  38.65    NaN   NaN    NaN    NaN    NaN
# 2007-04-25  9.52   57.60  32.80  38.59    NaN   NaN    NaN    NaN    NaN
# 2007-04-26  9.59   57.70  32.80  38.60    NaN   NaN    NaN    NaN    NaN
# 2007-04-27  9.55   57.50  32.72  38.40    NaN   NaN    NaN    NaN    NaN
# ...          ...     ...    ...    ...    ...   ...    ...    ...    ...
# 2022-09-12   NaN  115.40  55.15  97.25  56.35   NaN  23.26  28.56  82.60
# 2022-09-13   NaN  116.00  55.45  98.05  56.90   NaN  23.31  28.71  83.05
# 2022-09-14   NaN  113.65  54.95  95.95  55.85   NaN  23.03  28.35    NaN
# 2022-09-15   NaN  113.85  55.25  96.15  56.00   NaN  23.03  28.59  81.60
# 2022-09-16   NaN  112.55  54.80  95.10  55.30   NaN  23.06  28.28  80.85
#
# ...
